# %% [markdown]
# # import data

# %%
import pandas as pd

pd.set_option("display.max_columns", None)
pd.set_option("display.max_rows", None)

# %%
from google.colab import drive

drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
wefarm = pd.read_parquet("/content/drive/MyDrive/DataKit_WeFarm/wefarm.parquet")

# %%
wefarm["response_sent_dt"] = pd.to_datetime(wefarm["response_sent"], format="ISO8601")
wefarm["question_set_dt"] = pd.to_datetime(wefarm["question_sent"], format="ISO8601")

# %%
def parse_datetime_col(df, colstr):
  df[f'{colstr}_year'] = df[colstr].dt.year
  df[f'{colstr}_month'] = df[colstr].dt.month
  df[f'{colstr}_day'] = df[colstr].dt.day
  df[f'{colstr}_hour'] = df[colstr].dt.hour
  df[f'{colstr}_minute'] = df[colstr].dt.minute
  df[f'{colstr}_second'] = df[colstr].dt.second
  df[f'{colstr}_day_name'] = df[colstr].dt.day_name()
  df[f'{colstr}_day_of_week'] = df[colstr].dt.day_of_week
  df[f'{colstr}_month_name'] = df[colstr].dt.month_name()
  df[f'{colstr}_quarter'] = df[colstr].dt.quarter
  df[f'{colstr}_week'] = df[colstr].dt.isocalendar().week
  df[f'{colstr}_date'] = df[colstr].dt.date
  df[f'{colstr}_time'] = df[colstr].dt.time

  return df

# %%
wefarm = parse_datetime_col(wefarm, "response_sent_dt")
wefarm = parse_datetime_col(wefarm, "question_set_dt")

# %%
wefarm.head(5)
# Out:
#    question_id  question_user_id question_language  \
# 0      3849056            519124               nyn
# 1      3849061            521327               eng
# 2      3849077            307821               nyn
# 3      3849077            307821               nyn
# 4      3849077            307821               nyn
#
#                                     question_content question_topic  \
# 0       E ABA WEFARM OFFICES ZABO NIZISHANGWA NKAHI?           None
# 1  Q this goes to wefarm. is it possible to get f...           None
# 2  E ENTE YANJE EZAIRE ENYENA YASHOBERA. \nOBWIRE...         cattle
# 3  E ENTE YANJE EZAIRE ENYENA YASHOBERA. \nOBWIRE...         cattle
# 4  E ENTE YANJE EZAIRE ENYENA YASHOBERA. \nOBWIRE...            cat
#
#             question_sent  response_id  response_user_id response_language  \
# 0  2017-11-22 12:25:03+00     20691011            200868               nyn
# 1  2017-11-22 12:25:05+00      4334249            526113               eng
# 2  2017-11-22 12:25:08+00      3849291            296187               nyn
# 3  2017-11-22 12:25:08+00      3849291            296187               nyn
# 4  2017-11-22 12:25:08+00      3849291            296187               nyn
#
#                                     response_content response_topic  \
# 0                         E!23 Omubazi Ni Dudu Cipa'           None
# 1          Q1 which stage is marleks last vaccinated           None
# 2  Muhanguzi.Benon kuruga masha isingiro ente yaw...         tomato
# 3  Muhanguzi.Benon kuruga masha isingiro ente yaw...         cattle
# 4  Muhanguzi.Benon kuruga masha isingiro ente yaw...         tomato
#
#                    response_sent question_user_type question_user_status  \
# 0  2019-01-24 17:54:06.216221+00             farmer                 live
# 1         2018-01-04 08:57:28+00             farmer                 live
# 2         2017-11-22 12:35:26+00             farmer               zombie
# 3         2017-11-22 12:35:26+00             farmer               zombie
# 4         2017-11-22 12:35:26+00             farmer               zombie
#
#   question_user_country_code question_user_gender question_user_dob  \
# 0                         ug                 None              None
# 1                         ug                 None              None
# 2                         ug                 None              None
# 3                         ug                 None              None
# 4                         ug                 None              None
#
#   question_user_created_at response_user_type response_user_status  \
# 0   2017-11-18 13:09:11+00             farmer                 live
# 1   2017-11-20 11:55:48+00             farmer               zombie
# 2   2017-08-22 14:51:07+00             farmer               zombie
# 3   2017-08-22 14:51:07+00             farmer               zombie
# 4   2017-08-22 14:51:07+00             farmer               zombie
#
#   response_user_country_code response_user_gender response_user_dob  \
# 0                         ug                 None              None
# 1                         ug                 None              None
# 2                         ug                 None              None
# 3                         ug                 None              None
# 4                         ug                 None              None
#
#   response_user_created_at                 response_sent_dt  \
# 0   2017-05-09 09:19:33+00 2019-01-24 17:54:06.216221+00:00
# 1   2017-11-22 10:13:03+00        2018-01-04 08:57:28+00:00
# 2   2017-08-12 09:30:33+00        2017-11-22 12:35:26+00:00
# 3   2017-08-12 09:30:33+00        2017-11-22 12:35:26+00:00
# 4   2017-08-12 09:30:33+00        2017-11-22 12:35:26+00:00
#
#             question_set_dt  response_sent_dt_year  response_sent_dt_month  \
# 0 2017-11-22 12:25:03+00:00                   2019                       1
# 1 2017-11-22 12:25:05+00:00                   2018                       1
# 2 2017-11-22 12:25:08+00:00                   2017                      11
# 3 2017-11-22 12:25:08+00:00                   2017                      11
# 4 2017-11-22 12:25:08+00:00                   2017                      11
#
#    response_sent_dt_day  response_sent_dt_hour  response_sent_dt_minute  \
# 0                    24                     17                       54
# 1                     4                      8                       57
# 2                    22                     12                       35
# 3                    22                     12                       35
# 4                    22                     12                       35
#
#    response_sent_dt_second response_sent_dt_day_name  \
# 0                        6                  Thursday
# 1                       28                  Thursday
# 2                       26                 Wednesday
# 3                       26                 Wednesday
# 4                       26                 Wednesday
#
#    response_sent_dt_day_of_week response_sent_dt_month_name  \
# 0                             3                     January
# 1                             3                     January
# 2                             2                    November
# 3                             2                    November
# 4                             2                    November
#
#    response_sent_dt_quarter  response_sent_dt_week response_sent_dt_date  \
# 0                         1                      4            2019-01-24
# 1                         1                      1            2018-01-04
# 2                         4                     47            2017-11-22
# 3                         4                     47            2017-11-22
# 4                         4                     47            2017-11-22
#
#   response_sent_dt_time  question_set_dt_year  question_set_dt_month  \
# 0       17:54:06.216221                  2017                     11
# 1              08:57:28                  2017                     11
# 2              12:35:26                  2017                     11
# 3              12:35:26                  2017                     11
# 4              12:35:26                  2017                     11
#
#    question_set_dt_day  question_set_dt_hour  question_set_dt_minute  \
# 0                   22                    12                      25
# 1                   22                    12                      25
# 2                   22                    12                      25
# 3                   22                    12                      25
# 4                   22                    12                      25
#
#    question_set_dt_second question_set_dt_day_name  \
# 0                       3                Wednesday
# 1                       5                Wednesday
# 2                       8                Wednesday
# 3                       8                Wednesday
# 4                       8                Wednesday
#
#    question_set_dt_day_of_week question_set_dt_month_name  \
# 0                            2                   November
# 1                            2                   November
# 2                            2                   November
# 3                            2                   November
# 4                            2                   November
#
#    question_set_dt_quarter  question_set_dt_week question_set_dt_date  \
# 0                        4                    47           2017-11-22
# 1                        4                    47           2017-11-22
# 2                        4                    47           2017-11-22
# 3                        4                    47           2017-11-22
# 4                        4                    47           2017-11-22
#
#   question_set_dt_time
# 0             12:25:03
# 1             12:25:05
# 2             12:25:08
# 3             12:25:08
# 4             12:25:08

# %% [markdown]
# # count

# %%
response_user_id_gb = wefarm.groupby(["response_user_id"]
  ).agg({"response_id": "count"}
  ).sort_values(by=["response_id"], ascending=False)

# %%
ua_1_user_id_lst = response_user_id_gb[response_user_id_gb["response_id"] <= 5].index
ua_2_user_id_lst = response_user_id_gb[
  (response_user_id_gb["response_id"] > 5) &
  (response_user_id_gb["response_id"] <= 10)
].index
ua_3_user_id_lst = response_user_id_gb[
  (response_user_id_gb["response_id"] > 10) &
  (response_user_id_gb["response_id"] <= 25)
].index
ua_4_user_id_lst = response_user_id_gb[
  (response_user_id_gb["response_id"] > 25) &
  (response_user_id_gb["response_id"] <= 100)
].index

ua_5_user_id_lst = response_user_id_gb[(response_user_id_gb["response_id"] > 100)].index

# %%
import plotly.express as px
# px.histogram(response_user_id_gb["response_id"])

# %%
ua_segments_dct = {
    "1": ua_1_user_id_lst.tolist(),
    "2": ua_2_user_id_lst.tolist(),
    "3": ua_3_user_id_lst.tolist(),
    "4": ua_4_user_id_lst.tolist(),
    "5": ua_5_user_id_lst.tolist(),
  }

# %%
print([len(j) for j in ua_segments_dct.values()])
# Out:
# [508345, 146317, 154079, 116003, 35687]

# %%
sum(len(j) for j in ua_segments_dct.values())
# Out:
# 960431

# %%
wefarm["response_user_id"].nunique()
# Out:
# 960431

# %%
#Done

# %% [markdown]
# # speed

# %%
wefarm["question_response_min_diff"] = (wefarm["response_sent_dt"] - wefarm["question_set_dt"]).dt.total_seconds() / 60

# %%
rtime_user_id_gb = wefarm.groupby("response_user_id"
  ).agg({"question_response_min_diff": "mean"}
  ).sort_values(by="question_response_min_diff", ascending=True)

# %%
rt_5_user_id_lst = rtime_user_id_gb[rtime_user_id_gb["question_response_min_diff"] <= 30].index
rt_4_user_id_lst = rtime_user_id_gb[
  (rtime_user_id_gb["question_response_min_diff"] > 30) &
  (rtime_user_id_gb["question_response_min_diff"] <= 120)
].index
rt_3_user_id_lst = rtime_user_id_gb[
  (rtime_user_id_gb["question_response_min_diff"] > 120) &
  (rtime_user_id_gb["question_response_min_diff"] <= 720)
].index

rt_2_user_id_lst = rtime_user_id_gb[
  (rtime_user_id_gb["question_response_min_diff"] > 720) &
  (rtime_user_id_gb["question_response_min_diff"] <= 4320)
].index
rt_1_user_id_lst = rtime_user_id_gb[(rtime_user_id_gb["question_response_min_diff"] > 4320)].index

# %%
# px.histogram(rtime_user_id_gb["question_response_min_diff"])

# %%
rt_segment_dct = {
  "1": rt_1_user_id_lst.tolist(),
  "2": rt_2_user_id_lst.tolist(),
  "3": rt_3_user_id_lst.tolist(),
  "4": rt_4_user_id_lst.tolist(),
  "5": rt_5_user_id_lst.tolist()
  }

# %%
[len(j) for j in rt_segment_dct.values()]
# Out:
# [126412, 138599, 288549, 168787, 238084]

# %%
sum(len(j) for j in rt_segment_dct.values())
# Out:
# 960431

# %%
wefarm["response_user_id"].nunique()
# Out:
# 960431

# %%
# DONE

# %% [markdown]
# # conversation starters

# %%
question_response_count_gb = wefarm.groupby("question_id").count().sort_values(
  by="question_user_id", ascending=False
)
question_id_response_boundary_lst = question_response_count_gb[question_response_count_gb["question_user_id"]<=20].index

# %%
wefarm_sub = wefarm[wefarm["question_id"].isin(question_id_response_boundary_lst)]

# %%
wefarm_sorted = wefarm_sub.sort_values(["question_id", "question_response_min_diff"])

# %%
wefarm_sorted["response_order"] = wefarm_sorted.groupby("question_id").cumcount()+1

# %%
wefarm_sorted["total_responses"] = wefarm_sorted.groupby("question_id")["response_id"].transform("count")

# %%
wefarm_sorted["responses_after"] = wefarm_sorted["total_responses"] - wefarm_sorted["response_order"]

# %%
wefarm_sorted.loc[:20, ["question_id", "question_response_min_diff", "response_order", "total_responses", "responses_after"]]
# Out:
#     question_id  question_response_min_diff  response_order  total_responses  \
# 0       3849056               616649.053604               1                1
# 1       3849061                61712.383333               1                1
# 2       3849077                   10.300000               1                4
# 3       3849077                   10.300000               2                4
# 4       3849077                   10.300000               3                4
# 5       3849077                   10.300000               4                4
# 6       3849078                   13.433333               1                1
# 8       3849082                   16.366667               1                2
# 7       3849082               255197.476996               2                2
# 9       3849084                  180.950000               1                1
# 12      3849096                    2.900000               1                5
# 10      3849096                    3.433333               2                5
# 14      3849096                    5.933333               3                5
# 13      3849096                   28.483333               4                5
# 11      3849096                  232.050000               5                5
# 15      3849098                  745.133333               1                1
# 17      3849100                  203.366667               1                6
# 20      3849100                  203.366667               2                6
#
#     responses_after
# 0                 0
# 1                 0
# 2                 3
# 3                 2
# 4                 1
# 5                 0
# 6                 0
# 8                 1
# 7                 0
# 9                 0
# 12                4
# 10                3
# 14                2
# 13                1
# 11                0
# 15                0
# 17                5
# 20                4

# %%
cs_user_id_gb = wefarm_sorted.groupby("response_user_id"
  ).agg({"responses_after": "mean"}
  ).sort_values(by="responses_after", ascending=False)

# %%
cs_1_user_id_lst = cs_user_id_gb[cs_user_id_gb["responses_after"] <= 1.0].index
cs_2_user_id_lst = cs_user_id_gb[
  (cs_user_id_gb["responses_after"] > 1.0) &
  (cs_user_id_gb["responses_after"] <= 1.5)
].index
cs_3_user_id_lst = cs_user_id_gb[
  (cs_user_id_gb["responses_after"] > 1.5) &
  (cs_user_id_gb["responses_after"] <= 2.5)
].index

cs_4_user_id_lst = cs_user_id_gb[
  (cs_user_id_gb["responses_after"] > 2.5) &
  (cs_user_id_gb["responses_after"] <= 4)
].index
cs_5_user_id_lst = cs_user_id_gb[(cs_user_id_gb["responses_after"] > 4.0)].index

# %%
# px.histogram(responses_after["responses_after"])

# %%
cs_segments_dct = {
  "1":cs_1_user_id_lst.tolist(),
  "2":cs_2_user_id_lst.tolist(),
  "3":cs_3_user_id_lst.tolist(),
  "4":cs_4_user_id_lst.tolist(),
  "5":cs_5_user_id_lst.tolist()
}

# %%
[len(j) for j in cs_segments_dct.values()]
# Out:
# [400095, 129777, 225882, 139058, 60766]

# %%
sum(len(j) for j in cs_segments_dct.values())
# Out:
# 955578

# %%
wefarm["response_user_id"].nunique()
# Out:
# 960431

# %%
# DONE

# %% [markdown]
# # tenure

# %%
ten_user_id_gb = wefarm.groupby("response_user_id").agg({
  "response_sent_dt": ["min", "max"]
})

# %%
ten_user_id_gb.columns = ['_'.join(col) for col in ten_user_id_gb.columns]

# %%
ten_user_id_gb["earliest"] = ten_user_id_gb[[
    "response_sent_dt_min",
    "response_sent_dt_max"
]].min(axis=1)

# %%
ten_user_id_gb["latest"] = ten_user_id_gb[[
    "response_sent_dt_min",
    "response_sent_dt_max"
]].max(axis=1)

# %%
ten_user_id_gb["tenure"] = (ten_user_id_gb["latest"] - ten_user_id_gb["earliest"]).dt.days

# %%
# px.histogram(ten_user_id_gb["tenure"])

# %%
ten_1_user_id_lst = ten_user_id_gb[ten_user_id_gb["tenure"] <= 1].index
ten_2_user_id_lst = ten_user_id_gb[
  (ten_user_id_gb["tenure"] > 1) &
  (ten_user_id_gb["tenure"] <= 25)
].index
ten_3_user_id_lst = ten_user_id_gb[
  (ten_user_id_gb["tenure"] > 25) &
  (ten_user_id_gb["tenure"] <= 200)
].index

ten_4_user_id_lst = ten_user_id_gb[
  (ten_user_id_gb["tenure"] > 200) &
  (ten_user_id_gb["tenure"] <= 1000)
].index
ten_5_user_id_lst = ten_user_id_gb[(ten_user_id_gb["tenure"] > 1000)].index

# %%
ten_segments_dct = {
  "1": ten_1_user_id_lst.tolist(),
  "2": ten_2_user_id_lst.tolist(),
  "3": ten_3_user_id_lst.tolist(),
  "4": ten_4_user_id_lst.tolist(),
  "5": ten_5_user_id_lst.tolist()
}

# %%
[len(j) for j in ten_segments_dct.values()]
# Out:
# [286561, 87049, 248804, 310290, 27727]

# %%
sum([len(j) for j in ten_segments_dct.values()])
# Out:
# 960431

# %%
wefarm["response_user_id"].nunique()
# Out:
# 960431

# %%
# DONE

# %% [markdown]
# # export data to google drive

# %%
segment_dct = {
  "user_activity_post_count": ua_segments_dct,
  "speed_post_response": rt_segment_dct,
  "conversation_starters": cs_segments_dct,
  "tenure": ten_segments_dct
}

# %%
import json

with open("segment_user_ids.json", "w") as w:
  json.dump(segment_dct, w, indent=2)
# !cp segment_user_ids.json /content/drive/MyDrive/DataKit_WeFarm

# %%
# !ls /content/drive/MyDrive/DataKit_WeFarm
# Out:
# 'Copy of DataKit_Challenge 3 - identifying community leaders - LDA (1).ipynb'
# 'Copy of DataKit_Challenge 3 - identifying community leaders - LDA.ipynb'
#  Dashboard
# 'DataKit_Challenge 3 - identifying community leaders - keyword_categorization.ipynb'
# 'DataKit_Challenge 3 - identifying community leaders - LDA.ipynb'
# 'DataKit_Challenge 3 - identifying community leaders - leader_analysis_part1.ipynb'
# 'DataKit_Challenge 3 - identifying community leaders - leader_analysis_visuals.ipynb'
# 'DataKit_Challenge 3 - identifying community leaders - time_analysis.ipynb'
# 'DataKit_Challenge 3 - identifying community leaders - translation.ipynb'
# 'DataKit_Challenge 3 - identifying community leaders - translations_extraction.ipynb'
#  en_questions_cat_broad.parquet
#  en_questions_cat_niche.parquet
#  first_50_batches_sw.csv
#  segment_user_ids.json
#  translation_comparison_swh_lug_nyn.gsheet
#  Translations
#  wefarm.parquet
